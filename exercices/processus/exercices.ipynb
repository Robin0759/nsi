# %% [markdown]
# # EXERCICE 2

# %% [markdown]
# ### 1. Expliquer succinctement les différences entre les logiciels libres et les logiciels propriétaires.
# - Les logiciels libres peuvent être exploités, modifiés et utilisés par tous les utilisateurs
# - Les logiciels propriétaires sont des logiciels qui ne peuvent pas être modifiés par les utilisateurs, ni modifiés.
#
# ### 2.
# Un système d'exploitation est un ensemble de programmes qui établit une relation entre le matériel, les applications et l'utilisateur, en gérant notamment la mémoire, le processeur, les périphériques et en fournissant une interface pour faciliter l'utilisation de l'ordinateur.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. Indiquer le chemin absolu du fichier rapport.odt
#
# - /home/elsa/documents/boulot/rapport.odt

# %% [markdown]
# ### On suppose que le répertoire courant est le répertoire elsa
# 4. Indiquer le chemin relatif du fichier photo_1.jpg
# - ../max/images/photos_vac/photo_1.jpg
